# %%
from data_loaders import load_and_merge, load_classifications_mit

merged_df = load_and_merge(classifications_path="../data/classifications_GMF.csv", incidents_path="../data/incidents.csv")

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 326 entries, 16 to 63
# Data columns (total 30 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Namespace                                                 326 non-null    object
#  1   Incident ID                                               326 non-null    int64
#  2   Published                                                 326 non-null    bool
#  3   Known AI Goal                                             325 non-null    object
#  4   Known AI Goal Snippets                                    319 non-null    object
#  5   Known AI Goal Classification Discussion                   10 non-null     object
#  6   Potential AI Goal                                         3 non-null      object
#  7   Potential AI Goal Snippets                                3 non-null      object
# ...

# %%
GMF_df = load_classifications_mit(path="../data/classifications_GMF.csv")

# %%
GMF_df.head()
# Out:
#   Namespace  Incident ID  Published  \
# 0       GMF            1       True
# 1       GMF           13       True
# 2       GMF           31       True
# 3       GMF           34       True
# 4       GMF           36       True
#
#                                        Known AI Goal  \
# 0  Content Recommendation, Content Search, Hate S...
# 1                              Hate Speech Detection
# 2                                 Autonomous Driving
# 3                                 AI Voice Assistant
# 4                                   Face Recognition
#
#                               Known AI Goal Snippets  \
# 0  Snippet Text: An off-brand Paw Patrol video ca...
# 1  Snippet Text: However, computer scientists and...
# 2  Snippet Text: New Delhi, Dec 20 (IANS) The Del...
# 3  Snippet Text: According to one couple on Twitt...
# 4  Snippet Text: Chinese AI traffic cam mistook a...
#
#              Known AI Goal Classification Discussion Potential AI Goal  \
# ...
