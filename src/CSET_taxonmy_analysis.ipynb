# %%
from data_loaders import load_and_merge, load_classifications_mit

merged_df = load_and_merge(classifications_path="../data/classifications_CSETv1.csv", incidents_path="../data/incidents.csv")

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 214 entries, 80 to 208
# Data columns (total 74 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   Namespace                                                                      214 non-null    object
#  1   Incident ID                                                                    214 non-null    int64
#  2   Published                                                                      214 non-null    bool
#  3   Incident Number                                                                214 non-null    int64
#  4   Annotator                                                                      40 non-null     float64
#  5   Annotation Status                                                              213 non-null    object
# ...

# %%
GMF_df = load_classifications_mit(path="../data/classifications_CSETv1.csv")

# %%
GMF_df.head()
# Out:
#   Namespace  Incident ID  Published  Incident Number  Annotator  \
# 0    CSETv1          204      False                0        NaN
# 1    CSETv1          350      False                0        NaN
# 2    CSETv1          250      False                0        NaN
# 3    CSETv1          208      False                0        NaN
# 4    CSETv1          100       True              100        3.0
#
#          Annotation Status  Peer Reviewer  Quality Control Physical Objects  \
# 0                       --            NaN            False              NaN
# 1                       --            NaN            False              NaN
# 2                       --            NaN            False              NaN
# 3                       --            NaN            False              NaN
# 4  4. Peer review complete            1.0            False               no
#
#   Entertainment Industry  ...             Data Inputs  \
# 0                    NaN  ...                     NaN
# ...
